# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
statewise_df=pd.read_csv("crime_by_state.csv")

# %%
statewise_df
# Out:
#               STATE/UT  Year  Murder  Assault on women  \
# 0       ANDHRA PRADESH  2001      45                69
# 1       ANDHRA PRADESH  2002      60                98
# 2       ANDHRA PRADESH  2003      33                79
# 3       ANDHRA PRADESH  2004      39                66
# 4       ANDHRA PRADESH  2005      37                74
# ..                 ...   ...     ...               ...
# 451  TOTAL (ALL-INDIA)  2008     622              1453
# 452  TOTAL (ALL-INDIA)  2009     629              1350
# 453  TOTAL (ALL-INDIA)  2010     572              1350
# 454  TOTAL (ALL-INDIA)  2011     673              1557
# 455  TOTAL (ALL-INDIA)  2012     651              1576
#
#      Kidnapping and Abduction  Dacoity  Robbery  Arson  Hurt  \
# 0                          22        3        2      6   518
# 1                          18        0        4     12   568
# 2                          27        1       15      4   615
# ...

# %%
statewise_df.shape
# Out:
# (456, 12)

# %%
list(statewise_df.columns)
# Out:
# ['STATE/UT',
#  'Year',
#  'Murder',
#  'Assault on women',
#  'Kidnapping and Abduction',
#  'Dacoity',
#  'Robbery',
#  'Arson',
#  'Hurt',
#  'Prevention of atrocities (POA) Act',
#  'Protection of Civil Rights (PCR) Act',
#  'Other Crimes Against SCs']

# %%
statewise_df.sample(10)
# Out:
#              STATE/UT  Year  Murder  Assault on women  \
# 68                GOA  2009       0                 0
# 407             DELHI  2012       0                 0
# 370        CHANDIGARH  2011       0                 0
# 346    TOTAL (STATES)  2011     673              1557
# 428        PUDUCHERRY  2009       0                 0
# 273            SIKKIM  2010       0                 0
# 27              ASSAM  2004       0                 1
# 174       MAHARASHTRA  2007      16                80
# 304     UTTAR PRADESH  2005     323               224
# 100  HIMACHAL PRADESH  2005       0                 9
#
#      Kidnapping and Abduction  Dacoity  Robbery  Arson  Hurt  \
# 68                          0        0        0      0     1
# 407                         0        0        0      0     0
# 370                         0        0        0      0     0
# 346                       616       36       54    169  4247
# ...

# %%
statewise_df.head(10)
# Out:
#          STATE/UT  Year  Murder  Assault on women  Kidnapping and Abduction  \
# 0  ANDHRA PRADESH  2001      45                69                        22
# 1  ANDHRA PRADESH  2002      60                98                        18
# 2  ANDHRA PRADESH  2003      33                79                        27
# 3  ANDHRA PRADESH  2004      39                66                        28
# 4  ANDHRA PRADESH  2005      37                74                        21
# 5  ANDHRA PRADESH  2006      52                97                        12
# 6  ANDHRA PRADESH  2007      46               105                        25
# 7  ANDHRA PRADESH  2008      48                88                        18
# 8  ANDHRA PRADESH  2009      35                99                        19
# 9  ANDHRA PRADESH  2010      43               100                        18
#
#    Dacoity  Robbery  Arson  Hurt  Prevention of atrocities (POA) Act  \
# ...

# %%
statewise_df.tail(10)
# Out:
#               STATE/UT  Year  Murder  Assault on women  \
# 446  TOTAL (ALL-INDIA)  2003     581              1089
# 447  TOTAL (ALL-INDIA)  2004     654              1157
# 448  TOTAL (ALL-INDIA)  2005     669              1172
# 449  TOTAL (ALL-INDIA)  2006     673              1217
# 450  TOTAL (ALL-INDIA)  2007     674              1349
# 451  TOTAL (ALL-INDIA)  2008     622              1453
# 452  TOTAL (ALL-INDIA)  2009     629              1350
# 453  TOTAL (ALL-INDIA)  2010     572              1350
# 454  TOTAL (ALL-INDIA)  2011     673              1557
# 455  TOTAL (ALL-INDIA)  2012     651              1576
#
#      Kidnapping and Abduction  Dacoity  Robbery  Arson  Hurt  \
# 446                       232       24       70    204  3969
# 447                       253       26       72    211  3824
# 448                       258       26       80    210  3847
# 449                       280       30       90    226  3760
# ...

# %%
st=statewise_df.groupby(['STATE/UT'])[statewise_df.columns.values[2:]].sum().reset_index()

# %%
st
# Out:
#              STATE/UT  Murder  Assault on women  Kidnapping and Abduction  \
# 0       A & N ISLANDS       0                 0                         0
# 1      ANDHRA PRADESH     556              1110                       238
# 2   ARUNACHAL PRADESH       1                 0                         0
# 3               ASSAM      57                57                        96
# 4               BIHAR     286               284                       127
# 5          CHANDIGARH       0                 2                         0
# 6        CHHATTISGARH     117               661                        43
# 7        D & N HAVELI       0                 0                         2
# 8         DAMAN & DIU       0                 0                         0
# 9               DELHI       1                 0                         0
# 10                GOA       0                 1                         0
# 11            GUJARAT     204               325                       301
# ...

# %%
dfs=statewise_df.loc[statewise_df['STATE/UT']=='TOTAL (ALL-INDIA)']

# %%
dfs
# Out:
#               STATE/UT  Year  Murder  Assault on women  \
# 444  TOTAL (ALL-INDIA)  2001     763              1316
# 445  TOTAL (ALL-INDIA)  2002     739              1331
# 446  TOTAL (ALL-INDIA)  2003     581              1089
# 447  TOTAL (ALL-INDIA)  2004     654              1157
# 448  TOTAL (ALL-INDIA)  2005     669              1172
# 449  TOTAL (ALL-INDIA)  2006     673              1217
# 450  TOTAL (ALL-INDIA)  2007     674              1349
# 451  TOTAL (ALL-INDIA)  2008     622              1453
# 452  TOTAL (ALL-INDIA)  2009     629              1350
# 453  TOTAL (ALL-INDIA)  2010     572              1350
# 454  TOTAL (ALL-INDIA)  2011     673              1557
# 455  TOTAL (ALL-INDIA)  2012     651              1576
#
#      Kidnapping and Abduction  Dacoity  Robbery  Arson  Hurt  \
# 444                       400       41      133    354  4547
# 445                       319       29      105    322  4491
# ...

# %%
plt.figure(figsize=(12,8))
ax=plt.gca()
dfs.plot(kind='line',x='Year',y='Assault on women',ax=ax,color='red');
ax=plt.gca()
dfs.plot(kind='line',x='Year',y='Murder',ax=ax,color='blue');

# %%
plt.figure(figsize=(12,8))
ax=plt.gca()
dfs.plot(kind='line',x='Year',y='Prevention of atrocities (POA) Act',ax=ax);
ax=plt.gca()
dfs.plot(kind='line',x='Year',y='Other Crimes Against SCs',ax=ax);
